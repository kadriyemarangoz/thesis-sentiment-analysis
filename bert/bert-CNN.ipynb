# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
#Kütüphanelerin eklenmesi
import numpy as np #Bu kütüphane lineer cebir için kullandığımız kütüphane fonksiyonlarını içeriyor
import pandas as pd # verilerimizi işlemek için pandas kütüphanasini kullanıyoruz(örn pd.read_scv)
from sklearn.metrics import *
from sklearn.feature_extraction.text import TfidfVectorizer,CountVectorizer,TfidfTransformer
from sklearn.model_selection import KFold
import matplotlib.pyplot as plt

from utils import *
import json
import random
#from spacy.tokenizer import Tokenizer
from spacy.lang.tr import Turkish

from tqdm.notebook import tqdm
from nltk.corpus import stopwords
import re
import string
from sklearn.metrics import classification_report, accuracy_score, make_scorer


from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.layers import *

# DEEP LEARNING IMPORTS
from keras.models import Sequential, load_model
from keras.layers import Dense, Conv2D, Activation, Dropout, Flatten, MaxPooling2D,Bidirectional
from keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report, confusion_matrix


from numpy import array
from pickle import dump
from keras.preprocessing.text import Tokenizer
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Embedding
from sklearn.pipeline import Pipeline


import math
import bert
from tensorflow.keras import layers
from transformers import AutoModel, AutoTokenizer
import re
import random

# %%
column = ['tweets','duygu']
df = pd.read_excel("../dataset/kemik_pos_neg.xlsx")
df.columns=column
#veri setinin gösterilmesi
df=df.drop_duplicates()
df['tweets']=df['tweets'].str.lower()

# %%
df.loc[df.duygu=="olumlu","duygu"]=1
df.loc[df.duygu=="olumsuz","duygu"]=0
df[:4]
# Out:
#                                               tweets duygu
# 0              turkcell heryerde çekiyor kesin bilgi     1
# 1  turkcell olmak ayrıcalıktir çünkü kuzenlerin v...     1
# 2                       allahtan turkcell'liyim amin     1
# 3                        avea kaşar yaşasın turkcell     1

# %%
df=df.sample(frac=1).reset_index(drop=True)
df
# Out:
#                                                  tweets duygu
# 0     turkcell taşlara gelesin yaw ne oldu bu turkce...     0
# 1     ay turkcell bana bedava internet vermis yerim ...     1
# 2     bizde kaç yıllık turkcell hattımızı vodafona t...     0
# 3     turkcell , vodafone, avea boşuna reklam yapıyo...     0
# 4     en başarılı hopi kampanyası turkcell in derim ...     1
# ...                                                 ...   ...
# 9121  50 mbps bant genişliği olan turkcell superonli...     1
# 9122  bu turkcell 'e numaranızı taşımayın.. hele söz...     0
# 9123   ama ben senin 4 gb internetini yeğğğrim turkcell     1
# 9124             abv turkcell iligimi kemigimi kuruttun     0
# 9125  turkcell bana zarar vermektesiniz. eger ki fir...     0
#
# [9126 rows x 2 columns]

# %%
tweets = list(df['tweets'])

# %%
tokenizer = AutoTokenizer.from_pretrained("dbmdz/bert-base-turkish-cased",do_lower_case=True)

# %%
def tokenize_reviews(text_reviews):
    return tokenizer.convert_tokens_to_ids(tokenizer.tokenize(text_reviews))

# %%
#cnn
class TEXT_MODEL(tf.keras.Model):
    
    def __init__(self,
                 vocabulary_size,
                 embedding_dimensions=128,
                 cnn_filters=256,
                 dnn_units=512,
                 model_output_classes=2,
                 dropout_rate=0.3,
                 name="text_model"):
        super(TEXT_MODEL, self).__init__(name=name)
        
        self.embedding = layers.Embedding(vocabulary_size,
                                          embedding_dimensions)
        self.cnn_layer1 = layers.Conv1D(filters=cnn_filters,
                                        kernel_size=5,
                                        padding="same",
                                        activation="relu")
        self.pool = layers.GlobalMaxPool1D()
        
        self.dense_1 = layers.Dense(units=dnn_units, activation="relu")
        self.dropout = layers.Dropout(rate=dropout_rate)
        if model_output_classes == 2:
            self.last_dense = layers.Dense(units=1,
                                           activation="sigmoid")
        else:
            self.last_dense = layers.Dense(units=model_output_classes,
                                           activation="softmax")
    
    def call(self, inputs, training):
        l = self.embedding(inputs)
        l_1 = self.cnn_layer1(l) 
        l_1 = self.pool(l_1) 
        
        concatenated = tf.concat([l_1], axis=-1) # (batch_size, 3 * cnn_filters)
        concatenated = self.dense_1(concatenated)
        concatenated = self.dropout(concatenated, training)
        model_output = self.last_dense(concatenated)
        
        return model_output

# %%
VOCAB_LENGTH = len(tokenizer.vocab)
EMB_DIM = 200
CNN_FILTERS = 100
DNN_UNITS = 256
OUTPUT_CLASSES = 2
DROPOUT_RATE = 0.2
NB_EPOCHS = 50
early_stopping = EarlyStopping(monitor='loss', patience=3, verbose=True)

# %%
text_model = TEXT_MODEL(vocabulary_size=VOCAB_LENGTH,
                        embedding_dimensions=EMB_DIM,
                        cnn_filters=CNN_FILTERS,
                        dnn_units=DNN_UNITS,
                        model_output_classes=OUTPUT_CLASSES,
                        dropout_rate=DROPOUT_RATE)

# %%
if OUTPUT_CLASSES == 2:
    text_model.compile(loss="binary_crossentropy",
                       optimizer="adam",
                       metrics=['acc',tf.keras.metrics.Precision(),
                                  tf.keras.metrics.Recall()]) #binary cross çünkü sonucun pozitif yada negatif

# %%
# Define the K-fold Cross Validator
kfold = KFold(n_splits=10, shuffle=True)

# K-fold Cross Validation model evaluation
fold_no = 1
acc,pre,rec,f1=[],[],[],[]
BATCH_SIZE = 16

for train_index, test_index in kfold.split(df):
    # splitting Dataframe (dataset not included)
    
    train_df = df.iloc[train_index].tweets.tolist()
    test_df = df.iloc[test_index].tweets.tolist()
    train_y = np.array(df.iloc[train_index].duygu.tolist())
    test_y = np.array(df.iloc[test_index].duygu.tolist())

    tokenized_reviews_train = [tokenize_reviews(tweet) for tweet in train_df]
    tokenized_reviews_test = [tokenize_reviews(tweet) for tweet in test_df] 
    
    reviews_with_len_train = [[review, train_y[i], len(review)]
                     for i, review in enumerate(tokenized_reviews_train)]
    
    reviews_with_len_test = [[review, test_y[i], len(review)]
                     for i, review in enumerate(tokenized_reviews_test)]

    random.shuffle(reviews_with_len_train)
    random.shuffle(reviews_with_len_test)
    
    reviews_with_len_train.sort(key=lambda x: x[2])
    reviews_with_len_test.sort(key=lambda x: x[2])
    
    sorted_reviews_train = [(review_lab[0], review_lab[1]) for review_lab in reviews_with_len_train]
    sorted_reviews_test = [(review_lab[0], review_lab[1]) for review_lab in reviews_with_len_test]
    
    processed_dataset_test = tf.data.Dataset.from_generator(lambda: sorted_reviews_test, output_types=(tf.int32, tf.int32))
    processed_dataset_train = tf.data.Dataset.from_generator(lambda: sorted_reviews_train, output_types=(tf.int32, tf.int32))

    test_data = processed_dataset_test.padded_batch(BATCH_SIZE, padded_shapes=((None, ), ()))
    train_data = processed_dataset_train.padded_batch(BATCH_SIZE, padded_shapes=((None, ), ()))

    # Generate a print
    print('------------------------------------------------------------------------')
    print(f'Training for fold {fold_no} ...')

    text_model.fit(train_data, epochs=50,callbacks=early_stopping)
    
    loss, accuracy, precision, recall = text_model.evaluate(test_data)

    f1_score = 2 * (precision * recall) / (precision + recall)
    acc.append(accuracy)
    pre.append(precision)
    rec.append(recall)
    f1.append(f1_score)
    
    # Increase fold number
    fold_no = fold_no + 1
# Out:
# ------------------------------------------------------------------------
# Training for fold 1 ...
# Epoch 1/50
# 514/514 [==============================] - 54s 106ms/step - loss: 0.4570 - acc: 0.7761 - precision: 0.7550 - recall: 0.8197.4600 - acc: 0.7741 - prec
# Epoch 2/50
# 514/514 [==============================] - 109s 211ms/step - loss: 0.1574 - acc: 0.9401 - precision: 0.9407 - recall: 0.9398
# Epoch 3/50
# 514/514 [==============================] - 114s 221ms/step - loss: 0.0451 - acc: 0.9861 - precision: 0.9848 - recall: 0.9876
# Epoch 4/50
# 514/514 [==============================] - 113s 219ms/step - loss: 0.0159 - acc: 0.9951 - precision: 0.9956 - recall: 0.9947
# Epoch 5/50
# 514/514 [==============================] - 113s 220ms/step - loss: 0.0257 - acc: 0.9916 - precision: 0.9915 - recall: 0.9917
# Epoch 6/50
# 514/514 [==============================] - 114s 222ms/step - loss: 0.0192 - acc: 0.9938 - precision: 0.9942 - recall: 0.9934 - loss: 0.0181 - acc: 0.9945
# Epoch 7/50
# 514/514 [==============================] - 113s 219ms/step - loss: 0.0123 - acc: 0.9967 - precision: 0.9961 - recall: 0.9973 - loss: 0.0120 - acc: 0.9969 - prec - ETA: 3s - loss: 0.0124 - acc: 0.996
# Epoch 8/50
# 514/514 [==============================] - 97s 189ms/step - loss: 0.0117 - acc: 0.9967 - precision: 0.9971 - recall: 0.9964
# Epoch 9/50
# 514/514 [==============================] - 111s 216ms/step - loss: 0.0054 - acc: 0.9990 - precision: 0.9988 - recall: 0.9993
# Epoch 10/50
# 514/514 [==============================] - 114s 223ms/step - loss: 0.0028 - acc: 0.9996 - precision: 1.0000 - recall: 0.9993
# Epoch 11/50
# 514/514 [==============================] - 114s 222ms/step - loss: 0.0027 - acc: 0.9998 - precision: 0.9995 - recall: 1.0000
# Epoch 12/50
# 514/514 [==============================] - 108s 210ms/step - loss: 0.0023 - acc: 0.9998 - precision: 1.0000 - recall: 0.9995 - loss: 0.002
# Epoch 13/50
# 514/514 [==============================] - 96s 187ms/step - loss: 0.0023 - acc: 0.9998 - precision: 0.9995 - recall: 1.0000
# Epoch 14/50
# 514/514 [==============================] - 114s 221ms/step - loss: 0.0015 - acc: 0.9998 - precision: 1.0000 - recall: 0.9995
# Epoch 15/50
# 514/514 [==============================] - 113s 221ms/step - loss: 0.0030 - acc: 0.9998 - precision: 0.9995 - recall: 1.0000
# Epoch 16/50
# 514/514 [==============================] - 116s 225ms/step - loss: 6.6945e-04 - acc: 0.9998 - precision: 1.0000 - recall: 0.9995
# Epoch 17/50
# 514/514 [==============================] - 114s 222ms/step - loss: 0.0011 - acc: 0.9998 - precision: 0.9995 - recall: 1.0000
# Epoch 18/50
# 514/514 [==============================] - 114s 222ms/step - loss: 5.5861e-04 - acc: 0.9998 - precision: 1.0000 - recall: 0.9995
# Epoch 19/50
# 514/514 [==============================] - 114s 222ms/step - loss: 4.4125e-04 - acc: 0.9998 - precision: 0.9995 - recall: 1.000058s - loss: 4.3 - ETA: 44s - loss: 7.1256e-04 - a - ETA: 33s - loss: 6.2061e-04 - acc: 0.9997 - precision: 0.9993 - recall: 1.00 - ETA: 33s - loss: 6.1723e-04 - acc: 0.9997  -
# Epoch 20/50
# 514/514 [==============================] - 95s 185ms/step - loss: 3.1585e-04 - acc: 0.9998 - precision: 0.9995 - recall: 1.0000
# Epoch 21/50
# 514/514 [==============================] - 85s 165ms/step - loss: 3.9127e-04 - acc: 0.9999 - precision: 1.0000 - recall: 0.9998s - loss: 4.2599e-04 - acc: 0.9999 - precision: 1.0000 - re - E
# Epoch 22/50
# 514/514 [==============================] - 108s 209ms/step - loss: 3.3813e-04 - acc: 0.9998 - precision: 0.9998 - recall: 0.9998
# Epoch 23/50
# 514/514 [==============================] - 107s 209ms/step - loss: 3.3238e-04 - acc: 0.9998 - precision: 0.9995 - recall: 1.0000
# Epoch 00023: early stopping
# 58/58 [==============================] - 1s 19ms/step - loss: 1.2407 - acc: 0.8510 - precision: 0.8419 - recall: 0.8533
# ------------------------------------------------------------------------
# Training for fold 2 ...
# Epoch 1/50
# 514/514 [==============================] - 109s 211ms/step - loss: 0.1294 - acc: 0.9603 - precision: 0.9595 - recall: 0.9609
# Epoch 2/50
# 514/514 [==============================] - 107s 208ms/step - loss: 0.0077 - acc: 0.9974 - precision: 0.9973 - recall: 0.9976
# Epoch 3/50
# 514/514 [==============================] - 107s 208ms/step - loss: 0.0024 - acc: 0.9996 - precision: 0.9995 - recall: 0.9998
# Epoch 4/50
# 514/514 [==============================] - 109s 212ms/step - loss: 8.2610e-04 - acc: 0.9996 - precision: 0.9998 - recall: 0.9995
# Epoch 5/50
# 514/514 [==============================] - 111s 217ms/step - loss: 5.4656e-04 - acc: 0.9996 - precision: 0.9995 - recall: 0.9998
# Epoch 6/50
# 514/514 [==============================] - 109s 211ms/step - loss: 5.0088e-04 - acc: 0.9996 - precision: 0.9998 - recall: 0.9995
# Epoch 7/50
# 514/514 [==============================] - 110s 213ms/step - loss: 5.6176e-04 - acc: 0.9996 - precision: 0.9995 - recall: 0.9998
# Epoch 8/50
# 514/514 [==============================] - 108s 211ms/step - loss: 6.1689e-04 - acc: 0.9996 - precision: 0.9998 - recall: 0.9995 - loss: 6.2823e-04 - acc: 0.9996 - precision: 0
# Epoch 9/50
# 514/514 [==============================] - 109s 212ms/step - loss: 0.0011 - acc: 0.9996 - precision: 0.9995 - recall: 0.9998
# Epoch 00009: early stopping
# 58/58 [==============================] - 1s 20ms/step - loss: 0.0564 - acc: 0.9858 - precision: 0.9892 - recall: 0.9829
# ------------------------------------------------------------------------
# Training for fold 3 ...
# Epoch 1/50
# 514/514 [==============================] - 93s 181ms/step - loss: 0.0243 - acc: 0.9920 - precision: 0.9924 - recall: 0.9915
# Epoch 2/50
# 514/514 [==============================] - 110s 215ms/step - loss: 0.0060 - acc: 0.9979 - precision: 0.9980 - recall: 0.9978
# Epoch 3/50
# 514/514 [==============================] - 108s 210ms/step - loss: 8.7892e-04 - acc: 0.9995 - precision: 0.9995 - recall: 0.9995
# Epoch 4/50
# 514/514 [==============================] - 110s 213ms/step - loss: 4.6956e-04 - acc: 0.9996 - precision: 0.9998 - recall: 0.9995
# Epoch 5/50
# 514/514 [==============================] - 111s 215ms/step - loss: 4.0939e-04 - acc: 0.9998 - precision: 0.9998 - recall: 0.9998
# Epoch 6/50
# 514/514 [==============================] - 111s 217ms/step - loss: 3.8787e-04 - acc: 0.9996 - precision: 0.9995 - recall: 0.9998
# Epoch 7/50
# 514/514 [==============================] - 109s 212ms/step - loss: 3.9479e-04 - acc: 0.9998 - precision: 0.9998 - recall: 0.9998
# Epoch 8/50
# 514/514 [==============================] - 95s 184ms/step - loss: 3.7924e-04 - acc: 0.9998 - precision: 1.0000 - recall: 0.9995
# Epoch 9/50
# 514/514 [==============================] - 109s 213ms/step - loss: 4.6855e-04 - acc: 0.9996 - precision: 0.9995 - recall: 0.9998
# Epoch 10/50
# 514/514 [==============================] - 110s 213ms/step - loss: 3.8593e-04 - acc: 0.9998 - precision: 1.0000 - recall: 0.9995
# Epoch 11/50
# 514/514 [==============================] - 109s 212ms/step - loss: 7.7872e-04 - acc: 0.9998 - precision: 0.9998 - recall: 0.9998
# Epoch 00011: early stopping
# 58/58 [==============================] - 1s 17ms/step - loss: 0.0092 - acc: 0.9978 - precision: 0.9957 - recall: 1.0000
# ------------------------------------------------------------------------
# Training for fold 4 ...
# Epoch 1/50
# 514/514 [==============================] - 109s 212ms/step - loss: 0.0184 - acc: 0.9948 - precision: 0.9944 - recall: 0.9951
# Epoch 2/50
# 514/514 [==============================] - 96s 186ms/step - loss: 0.0067 - acc: 0.9982 - precision: 0.9981 - recall: 0.9983
# Epoch 3/50
# 514/514 [==============================] - 97s 188ms/step - loss: 5.2460e-04 - acc: 0.9998 - precision: 0.9995 - recall: 1.0000
# Epoch 4/50
# 514/514 [==============================] - 94s 184ms/step - loss: 3.6945e-04 - acc: 0.9998 - precision: 1.0000 - recall: 0.9995
# Epoch 5/50
# 514/514 [==============================] - 108s 210ms/step - loss: 3.8381e-04 - acc: 0.9998 - precision: 0.9998 - recall: 0.9998 - loss: 3.8555e-04 - acc: 0.9998 - precision: 0.9998 - recall
# Epoch 6/50
# 514/514 [==============================] - 92s 179ms/step - loss: 4.1347e-04 - acc: 0.9998 - precision: 0.9998 - recall: 0.9998s - loss: 4.3489e
# Epoch 7/50
# 514/514 [==============================] - 107s 209ms/step - loss: 4.0558e-04 - acc: 0.9996 - precision: 0.9995 - recall: 0.9998
# Epoch 00007: early stopping
# 58/58 [==============================] - 1s 18ms/step - loss: 0.0021 - acc: 0.9989 - precision: 1.0000 - recall: 0.9978
# ------------------------------------------------------------------------
# Training for fold 5 ...
# Epoch 1/50
# 514/514 [==============================] - 104s 202ms/step - loss: 0.0054 - acc: 0.9988 - precision: 0.9990 - recall: 0.9985
# Epoch 2/50
# 514/514 [==============================] - 106s 207ms/step - loss: 0.0065 - acc: 0.9982 - precision: 0.9978 - recall: 0.9985
# Epoch 3/50
# 514/514 [==============================] - 107s 208ms/step - loss: 0.0076 - acc: 0.9985 - precision: 0.9988 - recall: 0.9983
# Epoch 4/50
# 514/514 [==============================] - 104s 202ms/step - loss: 5.7344e-04 - acc: 0.9998 - precision: 0.9998 - recall: 0.999836s - loss: 8.3690e-04 - acc: 0.9996 - precision: 0.999 - ETA: 32s - loss: 7.9522 - ETA: 20
# Epoch 5/50
# 514/514 [==============================] - 109s 212ms/step - loss: 3.6780e-04 - acc: 0.9998 - precision: 0.9998 - recall: 0.9998
# Epoch 6/50
# 514/514 [==============================] - 107s 209ms/step - loss: 3.2697e-04 - acc: 0.9998 - precision: 0.9995 - recall: 1.0000
# Epoch 7/50
# 514/514 [==============================] - 96s 187ms/step - loss: 4.9085e-04 - acc: 0.9998 - precision: 0.9995 - recall: 1.0000
# Epoch 8/50
# 514/514 [==============================] - 107s 208ms/step - loss: 3.7375e-04 - acc: 0.9998 - precision: 0.9998 - recall: 0.9998
# Epoch 9/50
# 514/514 [==============================] - 94s 184ms/step - loss: 5.2090e-04 - acc: 0.9998 - precision: 0.9998 - recall: 0.9998
# Epoch 00009: early stopping
# 58/58 [==============================] - 1s 12ms/step - loss: 0.0201 - acc: 0.9978 - precision: 0.9958 - recall: 1.0000
# ------------------------------------------------------------------------
# Training for fold 6 ...
# Epoch 1/50
# 514/514 [==============================] - 106s 206ms/step - loss: 0.0061 - acc: 0.9981 - precision: 0.9983 - recall: 0.9978
# Epoch 2/50
# 514/514 [==============================] - 109s 212ms/step - loss: 0.0023 - acc: 0.9990 - precision: 0.9988 - recall: 0.9993
# Epoch 3/50
# 514/514 [==============================] - 105s 205ms/step - loss: 0.0042 - acc: 0.9984 - precision: 0.9983 - recall: 0.9985 - loss: 0.0043 - acc: 0.9984 - precision: 0.9983
# Epoch 4/50
# 514/514 [==============================] - 107s 209ms/step - loss: 0.0054 - acc: 0.9985 - precision: 0.9985 - recall: 0.9985
# Epoch 5/50
# 514/514 [==============================] - 106s 206ms/step - loss: 0.0027 - acc: 0.9991 - precision: 0.9993 - recall: 0.9990
# Epoch 00005: early stopping
# 58/58 [==============================] - 1s 18ms/step - loss: 0.0296 - acc: 0.9945 - precision: 0.9956 - recall: 0.9934
# ------------------------------------------------------------------------
# Training for fold 7 ...
# Epoch 1/50
# 514/514 [==============================] - 109s 211ms/step - loss: 0.0042 - acc: 0.9988 - precision: 0.9988 - recall: 0.9988
# Epoch 2/50
# 514/514 [==============================] - 89s 174ms/step - loss: 0.0040 - acc: 0.9990 - precision: 0.9993 - recall: 0.9988
# Epoch 3/50
# 514/514 [==============================] - 107s 209ms/step - loss: 7.0899e-04 - acc: 0.9996 - precision: 0.9995 - recall: 0.9998
# Epoch 4/50
# 514/514 [==============================] - 107s 208ms/step - loss: 3.9620e-04 - acc: 0.9998 - precision: 0.9998 - recall: 0.9998
# Epoch 5/50
# 514/514 [==============================] - 107s 209ms/step - loss: 8.4013e-04 - acc: 0.9998 - precision: 0.9998 - recall: 0.9998
# Epoch 6/50
# 514/514 [==============================] - 107s 208ms/step - loss: 2.8164e-04 - acc: 0.9999 - precision: 0.9998 - recall: 1.0000
# Epoch 7/50
# 514/514 [==============================] - 107s 208ms/step - loss: 4.1114e-04 - acc: 0.9998 - precision: 0.9998 - recall: 0.9998
# Epoch 8/50
# 514/514 [==============================] - 78s 152ms/step - loss: 4.0505e-04 - acc: 0.9998 - precision: 1.0000 - recall: 0.9995
# Epoch 9/50
# 514/514 [==============================] - 101s 196ms/step - loss: 3.8706e-04 - acc: 0.9995 - precision: 0.9995 - recall: 0.9995
# Epoch 00009: early stopping
# 57/57 [==============================] - 1s 17ms/step - loss: 1.7371e-06 - acc: 1.0000 - precision: 1.0000 - recall: 1.0000
# ------------------------------------------------------------------------
# Training for fold 8 ...
# Epoch 1/50
# 514/514 [==============================] - 108s 210ms/step - loss: 3.8768e-04 - acc: 0.9996 - precision: 0.9995 - recall: 0.9998
# Epoch 2/50
# 514/514 [==============================] - 106s 207ms/step - loss: 4.4565e-04 - acc: 0.9996 - precision: 0.9995 - recall: 0.9998
# Epoch 3/50
# 514/514 [==============================] - 107s 209ms/step - loss: 3.5940e-04 - acc: 0.9998 - precision: 0.9998 - recall: 0.9998
# Epoch 4/50
# 514/514 [==============================] - 90s 174ms/step - loss: 3.6020e-04 - acc: 0.9996 - precision: 0.9998 - recall: 0.9995
# Epoch 5/50
# 514/514 [==============================] - 109s 211ms/step - loss: 3.5784e-04 - acc: 0.9996 - precision: 0.9995 - recall: 0.9998
# Epoch 6/50
# 514/514 [==============================] - 108s 210ms/step - loss: 3.6097e-04 - acc: 0.9998 - precision: 0.9998 - recall: 0.9998 - loss: 3.7062e-04 - acc: 0.9998 - prec
# Epoch 7/50
# 514/514 [==============================] - 106s 206ms/step - loss: 4.0951e-04 - acc: 0.9998 - precision: 0.9995 - recall: 1.0000
# Epoch 8/50
# 514/514 [==============================] - 107s 209ms/step - loss: 8.2886e-04 - acc: 0.9995 - precision: 0.9995 - recall: 0.9995
# Epoch 00008: early stopping
# 57/57 [==============================] - 1s 16ms/step - loss: 1.0389e-04 - acc: 1.0000 - precision: 1.0000 - recall: 1.0000
# ------------------------------------------------------------------------
# Training for fold 9 ...
# Epoch 1/50
# 514/514 [==============================] - 107s 208ms/step - loss: 0.0168 - acc: 0.9973 - precision: 0.9973 - recall: 0.9973
# Epoch 2/50
# 514/514 [==============================] - 108s 211ms/step - loss: 0.0081 - acc: 0.9987 - precision: 0.9988 - recall: 0.9985
# Epoch 3/50
# 514/514 [==============================] - 92s 178ms/step - loss: 0.0027 - acc: 0.9994 - precision: 0.9995 - recall: 0.9993s - loss: 0.0028 - acc: 0.9994 - precision: 0.999
# Epoch 4/50
# 514/514 [==============================] - 106s 207ms/step - loss: 2.3391e-04 - acc: 0.9999 - precision: 0.9998 - recall: 1.0000
# Epoch 5/50
# 514/514 [==============================] - 90s 175ms/step - loss: 2.2981e-05 - acc: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 6/50
# 514/514 [==============================] - 108s 209ms/step - loss: 2.5925e-05 - acc: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 7/50
# 514/514 [==============================] - 108s 210ms/step - loss: 8.7174e-05 - acc: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 8/50
# 514/514 [==============================] - 74s 143ms/step - loss: 1.4408e-05 - acc: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 9/50
# 514/514 [==============================] - 75s 145ms/step - loss: 5.2539e-06 - acc: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 10/50
# 514/514 [==============================] - 74s 145ms/step - loss: 3.6461e-05 - acc: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 11/50
# 514/514 [==============================] - 77s 151ms/step - loss: 1.1917e-05 - acc: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 12/50
# 514/514 [==============================] - 72s 141ms/step - loss: 2.3917e-06 - acc: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 13/50
# 514/514 [==============================] - 73s 142ms/step - loss: 1.5108e-06 - acc: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 14/50
# 514/514 [==============================] - 74s 144ms/step - loss: 6.0318e-06 - acc: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 15/50
# 514/514 [==============================] - 73s 143ms/step - loss: 1.1905e-06 - acc: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 16/50
# 514/514 [==============================] - 73s 143ms/step - loss: 4.0175e-07 - acc: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 17/50
# 514/514 [==============================] - 73s 142ms/step - loss: 2.2170e-07 - acc: 1.0000 - precision: 1.0000 - recall: 1.0000s - loss: 2.2528e-07 - acc: 1.0000 - precision:
# Epoch 18/50
# 514/514 [==============================] - 52s 101ms/step - loss: 1.3416e-05 - acc: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 19/50
# 514/514 [==============================] - 68s 132ms/step - loss: 2.7465e-07 - acc: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 20/50
# 514/514 [==============================] - 74s 145ms/step - loss: 2.4673e-08 - acc: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 21/50
# 514/514 [==============================] - 73s 142ms/step - loss: 6.1848e-08 - acc: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 22/50
# 514/514 [==============================] - 74s 144ms/step - loss: 1.1538e-08 - acc: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 23/50
# 514/514 [==============================] - 72s 139ms/step - loss: 0.0079 - acc: 0.9987 - precision: 0.9985 - recall: 0.9988
# Epoch 24/50
# 514/514 [==============================] - 72s 140ms/step - loss: 0.0139 - acc: 0.9977 - precision: 0.9978 - recall: 0.9976
# Epoch 25/50
# 514/514 [==============================] - 73s 142ms/step - loss: 0.0072 - acc: 0.9993 - precision: 0.9993 - recall: 0.9993s - loss: 0.0073 - acc: 0.9993 - precision: 0.9993 -
# Epoch 00025: early stopping
# 57/57 [==============================] - 1s 14ms/step - loss: 0.0537 - acc: 0.9923 - precision: 0.9933 - recall: 0.9911
# ------------------------------------------------------------------------
# Training for fold 10 ...
# Epoch 1/50
# 514/514 [==============================] - 74s 144ms/step - loss: 0.0092 - acc: 0.9987 - precision: 0.9990 - recall: 0.9983
# Epoch 2/50
# 514/514 [==============================] - 73s 142ms/step - loss: 0.0017 - acc: 0.9994 - precision: 0.9993 - recall: 0.9995
# Epoch 3/50
# 514/514 [==============================] - 72s 140ms/step - loss: 7.0805e-04 - acc: 0.9998 - precision: 1.0000 - recall: 0.9995
# Epoch 4/50
# 514/514 [==============================] - 73s 142ms/step - loss: 5.3531e-04 - acc: 0.9998 - precision: 0.9998 - recall: 0.9998
# Epoch 5/50
# 514/514 [==============================] - 73s 142ms/step - loss: 4.8119e-04 - acc: 0.9998 - precision: 1.0000 - recall: 0.9995
# Epoch 6/50
# 514/514 [==============================] - 65s 127ms/step - loss: 3.7282e-04 - acc: 0.9998 - precision: 1.0000 - recall: 0.9995
# Epoch 7/50
# 514/514 [==============================] - 76s 149ms/step - loss: 4.2361e-04 - acc: 0.9998 - precision: 0.9995 - recall: 1.0000s - loss: 4.3408e-04 - acc: 0.9998 - precis
# Epoch 8/50
# 514/514 [==============================] - 77s 149ms/step - loss: 4.2818e-04 - acc: 0.9998 - precision: 1.0000 - recall: 0.9995
# Epoch 9/50
# 514/514 [==============================] - 75s 147ms/step - loss: 4.3187e-04 - acc: 0.9998 - precision: 0.9998 - recall: 0.9998s - loss: 4.3473e-04 - acc: 0.9998 - precision: 0.9998 - reca
# Epoch 00009: early stopping
# 57/57 [==============================] - 1s 14ms/step - loss: 0.0097 - acc: 0.9978 - precision: 0.9956 - recall: 1.0000

# %%
def Average(lst):
    return sum(lst) / len(lst)

# %%
print('test Accuracy: %f' % (Average(acc)))
print('test precision: %f' % (Average(pre)))
print('test recall: %f' % (Average(rec)))
print('test f1_score: %f' % (Average(f1)))
# Out:
# test Accuracy: 0.981598
# test precision: 0.980711
# test recall: 0.981852
# test f1_score: 0.981275
