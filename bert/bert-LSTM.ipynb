# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
#Kütüphanelerin eklenmesi
import numpy as np #Bu kütüphane lineer cebir için kullandığımız kütüphane fonksiyonlarını içeriyor
import pandas as pd # verilerimizi işlemek için pandas kütüphanasini kullanıyoruz(örn pd.read_scv)
from sklearn.metrics import *
from sklearn.feature_extraction.text import TfidfVectorizer,CountVectorizer,TfidfTransformer
from sklearn.model_selection import KFold
import matplotlib.pyplot as plt

from utils import *
import json
import random
#from spacy.tokenizer import Tokenizer
from spacy.lang.tr import Turkish

from tqdm.notebook import tqdm
from nltk.corpus import stopwords
import re
import string
from sklearn.metrics import classification_report, accuracy_score, make_scorer


from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.layers import *

# DEEP LEARNING IMPORTS
from keras.models import Sequential, load_model
from keras.layers import Dense, Conv2D, Activation, Dropout, Flatten, MaxPooling2D,Bidirectional
from keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report, confusion_matrix


from numpy import array
from pickle import dump
from keras.preprocessing.text import Tokenizer
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Embedding
from sklearn.pipeline import Pipeline


import math
import bert
from tensorflow.keras import layers
from transformers import AutoModel, AutoTokenizer
import re
import random

# %%
column = ['tweets','duygu']
df = pd.read_excel("../dataset/kemik_pos_neg.xlsx")
df.columns=column
#veri setinin gösterilmesi
df=df.drop_duplicates()
df['tweets']=df['tweets'].str.lower()

# %%
df.loc[df.duygu=="olumlu","duygu"]=1
df.loc[df.duygu=="olumsuz","duygu"]=0
df[:4]
# Out:
#                                               tweets duygu
# 0              turkcell heryerde çekiyor kesin bilgi     1
# 1  turkcell olmak ayrıcalıktir çünkü kuzenlerin v...     1
# 2                       allahtan turkcell'liyim amin     1
# 3                        avea kaşar yaşasın turkcell     1

# %%
df=df.sample(frac=1).reset_index(drop=True)
df
# Out:
#                                                  tweets duygu
# 0              kahrolasi vodafone. turkcell'e geciyorum     1
# 1                                iyi ki varsın turkcell     1
# 2     allah kimseye "turkcell kazık ama çok iyi çeki...     0
# 3     sdfogt 1 haftadır öyle zaten kanki. numaramı f...     1
# 4     turkcell geliştirdiği teknoloji ile doğal afet...     1
# ...                                                 ...   ...
# 9121  neyse fark etmez, silindiyse bile bir kez daha...     0
# 9122  mesela ben turkcell calisanlarinin gerizekali ...     0
# 9123  @turktelekom neden kampanya larınızda akk sız ...     1
# 9124  kamil koç genç turkcell kampanyası 1 bilet ala...     1
# 9125  turkcell 4.5g kapsamasını denizlere de taşıdığ...     1
#
# [9126 rows x 2 columns]

# %%
tweets = list(df['tweets'])

# %%
tokenizer = AutoTokenizer.from_pretrained("dbmdz/bert-base-turkish-cased",do_lower_case=True)

# %%
def tokenize_reviews(text_reviews):
    return tokenizer.convert_tokens_to_ids(tokenizer.tokenize(text_reviews))

# %%
#lstm
class TEXT_MODEL(tf.keras.Model):
    
    def __init__(self,
                 vocabulary_size,
                 embedding_dimensions=128,
                 cnn_filters=256,
                 dnn_units=512,
                 model_output_classes=2,
                 dropout_rate=0.3,
                 name="text_model"):
        super(TEXT_MODEL, self).__init__(name=name)
        
        self.embedding = layers.Embedding(vocabulary_size,
                                          embedding_dimensions)
        self.lstm_layer1 = layers.LSTM(128,return_sequences=False,recurrent_dropout=0.2)
        
        self.dense_1 = layers.Dense(units=dnn_units, activation="relu")
        self.dropout = layers.Dropout(rate=dropout_rate)
        if model_output_classes == 2:
            self.last_dense = layers.Dense(units=1,
                                           activation="sigmoid")
        else:
            self.last_dense = layers.Dense(units=model_output_classes,
                                           activation="softmax")
    
    def call(self, inputs, training):
        l = self.embedding(inputs)
        l_1 = self.lstm_layer1(l) 
        
        concatenated = tf.concat([l_1], axis=-1) # (batch_size, 3 * cnn_filters)
        concatenated = self.dense_1(concatenated)
        concatenated = self.dropout(concatenated, training)
        model_output = self.last_dense(concatenated)
        
        return model_output

# %%
VOCAB_LENGTH = len(tokenizer.vocab)
EMB_DIM = 200
CNN_FILTERS = 100
DNN_UNITS = 256
OUTPUT_CLASSES = 2
DROPOUT_RATE = 0.2
NB_EPOCHS = 50
early_stopping = EarlyStopping(monitor='loss', patience=3, verbose=True)

# %%
text_model = TEXT_MODEL(vocabulary_size=VOCAB_LENGTH,
                        embedding_dimensions=EMB_DIM,
                        cnn_filters=CNN_FILTERS,
                        dnn_units=DNN_UNITS,
                        model_output_classes=OUTPUT_CLASSES,
                        dropout_rate=DROPOUT_RATE)

# %%
if OUTPUT_CLASSES == 2:
    text_model.compile(loss="binary_crossentropy",
                       optimizer="adam",
                       metrics=['acc',tf.keras.metrics.Precision(),
                                  tf.keras.metrics.Recall()]) #binary cross çünkü sonucun pozitif yada negatif

# %%
# Define the K-fold Cross Validator
kfold = KFold(n_splits=10, shuffle=True)

# K-fold Cross Validation model evaluation
fold_no = 1
acc,pre,rec,f1=[],[],[],[]
BATCH_SIZE = 16

for train_index, test_index in kfold.split(df):
    # splitting Dataframe (dataset not included)
    
    train_df = df.iloc[train_index].tweets.tolist()
    test_df = df.iloc[test_index].tweets.tolist()
    train_y = np.array(df.iloc[train_index].duygu.tolist())
    test_y = np.array(df.iloc[test_index].duygu.tolist())

    tokenized_reviews_train = [tokenize_reviews(tweet) for tweet in train_df]
    tokenized_reviews_test = [tokenize_reviews(tweet) for tweet in test_df] 
    
    reviews_with_len_train = [[review, train_y[i], len(review)]
                     for i, review in enumerate(tokenized_reviews_train)]
    
    reviews_with_len_test = [[review, test_y[i], len(review)]
                     for i, review in enumerate(tokenized_reviews_test)]

    random.shuffle(reviews_with_len_train)
    random.shuffle(reviews_with_len_test)
    
    reviews_with_len_train.sort(key=lambda x: x[2])
    reviews_with_len_test.sort(key=lambda x: x[2])
    
    sorted_reviews_train = [(review_lab[0], review_lab[1]) for review_lab in reviews_with_len_train]
    sorted_reviews_test = [(review_lab[0], review_lab[1]) for review_lab in reviews_with_len_test]
    
    processed_dataset_test = tf.data.Dataset.from_generator(lambda: sorted_reviews_test, output_types=(tf.int32, tf.int32))
    processed_dataset_train = tf.data.Dataset.from_generator(lambda: sorted_reviews_train, output_types=(tf.int32, tf.int32))

    test_data = processed_dataset_test.padded_batch(BATCH_SIZE, padded_shapes=((None, ), ()))
    train_data = processed_dataset_train.padded_batch(BATCH_SIZE, padded_shapes=((None, ), ()))

    # Generate a print
    print('------------------------------------------------------------------------')
    print(f'Training for fold {fold_no} ...')

    text_model.fit(train_data, epochs=50,callbacks=early_stopping)
    
    loss, accuracy, precision, recall = text_model.evaluate(test_data)

    f1_score = 2 * (precision * recall) / (precision + recall)
    acc.append(accuracy)
    pre.append(precision)
    rec.append(recall)
    f1.append(f1_score)
    
    # Increase fold number
    fold_no = fold_no + 1
# Out:
# ------------------------------------------------------------------------
# Training for fold 1 ...
# Epoch 1/50
# 514/514 [==============================] - 118s 230ms/step - loss: 0.4647 - acc: 0.7800 - precision: 0.7620 - recall: 0.8148
# Epoch 2/50
# 514/514 [==============================] - 111s 217ms/step - loss: 0.2451 - acc: 0.9077 - precision: 0.9056 - recall: 0.9105
# Epoch 3/50
# 514/514 [==============================] - 113s 220ms/step - loss: 0.1249 - acc: 0.9574 - precision: 0.9543 - recall: 0.9608
# Epoch 4/50
# 514/514 [==============================] - 112s 218ms/step - loss: 0.0962 - acc: 0.9659 - precision: 0.9646 - recall: 0.9674
# Epoch 5/50
# 514/514 [==============================] - 113s 220ms/step - loss: 0.0906 - acc: 0.9665 - precision: 0.9653 - recall: 0.9679
# Epoch 6/50
# 514/514 [==============================] - 113s 219ms/step - loss: 0.0657 - acc: 0.9770 - precision: 0.9776 - recall: 0.9764
# Epoch 7/50
# 514/514 [==============================] - 99s 193ms/step - loss: 0.0582 - acc: 0.9817 - precision: 0.9815 - recall: 0.9820
# Epoch 8/50
# 514/514 [==============================] - 113s 220ms/step - loss: 0.0494 - acc: 0.9832 - precision: 0.9834 - recall: 0.9830
# Epoch 9/50
# 514/514 [==============================] - 109s 212ms/step - loss: 0.0342 - acc: 0.9887 - precision: 0.9886 - recall: 0.9888
# Epoch 10/50
# 514/514 [==============================] - 111s 215ms/step - loss: 0.0295 - acc: 0.9901 - precision: 0.9912 - recall: 0.9891
# Epoch 11/50
# 514/514 [==============================] - 104s 202ms/step - loss: 0.0316 - acc: 0.9890 - precision: 0.9883 - recall: 0.9898
# Epoch 12/50
# 514/514 [==============================] - 99s 193ms/step - loss: 0.0263 - acc: 0.9911 - precision: 0.9920 - recall: 0.9903
# Epoch 13/50
# 514/514 [==============================] - 112s 217ms/step - loss: 0.0243 - acc: 0.9922 - precision: 0.9922 - recall: 0.9922
# Epoch 14/50
# 514/514 [==============================] - 111s 216ms/step - loss: 0.0177 - acc: 0.9946 - precision: 0.9954 - recall: 0.9939
# Epoch 15/50
# 514/514 [==============================] - 112s 218ms/step - loss: 0.0105 - acc: 0.9971 - precision: 0.9976 - recall: 0.9966
# Epoch 16/50
# 514/514 [==============================] - 112s 217ms/step - loss: 0.0066 - acc: 0.9981 - precision: 0.9983 - recall: 0.9978
# Epoch 17/50
# 514/514 [==============================] - 113s 219ms/step - loss: 0.0102 - acc: 0.9967 - precision: 0.9968 - recall: 0.9966
# Epoch 18/50
# 514/514 [==============================] - 112s 218ms/step - loss: 0.0117 - acc: 0.9961 - precision: 0.9959 - recall: 0.9964
# Epoch 19/50
# 514/514 [==============================] - 97s 190ms/step - loss: 0.0089 - acc: 0.9974 - precision: 0.9976 - recall: 0.9973
# Epoch 00019: early stopping
# 58/58 [==============================] - 1s 23ms/step - loss: 1.5515 - acc: 0.7755 - precision: 0.7331 - recall: 0.8609
# ------------------------------------------------------------------------
# Training for fold 2 ...
# Epoch 1/50
# 514/514 [==============================] - 107s 209ms/step - loss: 0.1018 - acc: 0.9733 - precision: 0.9732 - recall: 0.9734
# Epoch 2/50
# 514/514 [==============================] - 106s 205ms/step - loss: 0.0322 - acc: 0.9928 - precision: 0.9929 - recall: 0.9927 - loss: 0.0312 - acc: 0.9930 - prec
# Epoch 3/50
# 514/514 [==============================] - 99s 193ms/step - loss: 0.0098 - acc: 0.9974 - precision: 0.9980 - recall: 0.9968
# Epoch 4/50
# 514/514 [==============================] - 107s 209ms/step - loss: 0.0071 - acc: 0.9979 - precision: 0.9978 - recall: 0.9981
# Epoch 5/50
# 514/514 [==============================] - 107s 207ms/step - loss: 0.0073 - acc: 0.9981 - precision: 0.9978 - recall: 0.9983
# Epoch 6/50
# 514/514 [==============================] - 106s 206ms/step - loss: 0.0044 - acc: 0.9982 - precision: 0.9983 - recall: 0.9981
# Epoch 7/50
# 514/514 [==============================] - 107s 208ms/step - loss: 0.0031 - acc: 0.9990 - precision: 0.9988 - recall: 0.9993
# Epoch 8/50
# 514/514 [==============================] - 105s 205ms/step - loss: 0.0077 - acc: 0.9974 - precision: 0.9976 - recall: 0.9973
# Epoch 9/50
# 514/514 [==============================] - 107s 208ms/step - loss: 0.0020 - acc: 0.9991 - precision: 0.9990 - recall: 0.9993
# Epoch 10/50
# 514/514 [==============================] - 108s 210ms/step - loss: 8.5482e-04 - acc: 0.9995 - precision: 0.9995 - recall: 0.9995
# Epoch 11/50
# 514/514 [==============================] - 106s 206ms/step - loss: 7.1105e-04 - acc: 0.9996 - precision: 0.9995 - recall: 0.9998
# Epoch 12/50
# 514/514 [==============================] - 107s 209ms/step - loss: 4.3694e-04 - acc: 0.9998 - precision: 1.0000 - recall: 0.9995
# Epoch 13/50
# 514/514 [==============================] - 86s 168ms/step - loss: 7.4888e-04 - acc: 0.9998 - precision: 0.9998 - recall: 0.9998
# Epoch 14/50
# 514/514 [==============================] - 103s 200ms/step - loss: 5.8505e-04 - acc: 0.9996 - precision: 0.9998 - recall: 0.9995
# Epoch 15/50
# 514/514 [==============================] - 104s 203ms/step - loss: 3.5830e-04 - acc: 0.9996 - precision: 0.9995 - recall: 0.9998
# Epoch 16/50
# 514/514 [==============================] - 105s 204ms/step - loss: 3.5938e-04 - acc: 0.9996 - precision: 0.9995 - recall: 0.9998
# Epoch 17/50
# 514/514 [==============================] - 106s 207ms/step - loss: 3.6171e-04 - acc: 0.9998 - precision: 0.9998 - recall: 0.9998
# Epoch 18/50
# 514/514 [==============================] - 106s 207ms/step - loss: 3.5146e-04 - acc: 0.9998 - precision: 0.9998 - recall: 0.9998
# Epoch 19/50
# 514/514 [==============================] - 106s 206ms/step - loss: 3.5486e-04 - acc: 0.9996 - precision: 0.9995 - recall: 0.9998
# Epoch 20/50
# 514/514 [==============================] - 108s 210ms/step - loss: 3.4135e-04 - acc: 0.9998 - precision: 1.0000 - recall: 0.9995
# Epoch 21/50
# 514/514 [==============================] - 92s 179ms/step - loss: 3.5049e-04 - acc: 0.9998 - precision: 1.0000 - recall: 0.9995
# Epoch 22/50
# 514/514 [==============================] - 107s 208ms/step - loss: 3.3944e-04 - acc: 0.9999 - precision: 1.0000 - recall: 0.9998
# Epoch 23/50
# 514/514 [==============================] - 106s 206ms/step - loss: 3.3793e-04 - acc: 0.9999 - precision: 1.0000 - recall: 0.9998
# Epoch 24/50
# 514/514 [==============================] - 106s 205ms/step - loss: 3.4036e-04 - acc: 0.9998 - precision: 1.0000 - recall: 0.9995
# Epoch 25/50
# 514/514 [==============================] - 96s 187ms/step - loss: 3.4813e-04 - acc: 0.9996 - precision: 0.9995 - recall: 0.9998
# Epoch 26/50
# 514/514 [==============================] - 107s 209ms/step - loss: 0.0205 - acc: 0.9939 - precision: 0.9941 - recall: 0.9937
# Epoch 00026: early stopping
# 58/58 [==============================] - 2s 26ms/step - loss: 0.1965 - acc: 0.9398 - precision: 0.9451 - recall: 0.9348
# ------------------------------------------------------------------------
# Training for fold 3 ...
# Epoch 1/50
# 514/514 [==============================] - 98s 190ms/step - loss: 0.0502 - acc: 0.9849 - precision: 0.9868 - recall: 0.9830
# Epoch 2/50
# 514/514 [==============================] - 98s 190ms/step - loss: 0.0054 - acc: 0.9988 - precision: 0.9990 - recall: 0.9985
# Epoch 3/50
# 514/514 [==============================] - 108s 210ms/step - loss: 7.9823e-04 - acc: 0.9996 - precision: 0.9995 - recall: 0.9998
# Epoch 4/50
# 514/514 [==============================] - 93s 180ms/step - loss: 5.9865e-04 - acc: 0.9996 - precision: 0.9998 - recall: 0.9995
# Epoch 5/50
# 514/514 [==============================] - 103s 200ms/step - loss: 5.0555e-04 - acc: 0.9996 - precision: 0.9995 - recall: 0.9998
# Epoch 6/50
# 514/514 [==============================] - 98s 190ms/step - loss: 4.4387e-04 - acc: 0.9998 - precision: 0.9998 - recall: 0.9998
# Epoch 7/50
# 514/514 [==============================] - 107s 208ms/step - loss: 3.7327e-04 - acc: 0.9996 - precision: 0.9995 - recall: 0.9998
# Epoch 8/50
# 514/514 [==============================] - 105s 204ms/step - loss: 3.5986e-04 - acc: 0.9999 - precision: 0.9998 - recall: 1.0000
# Epoch 9/50
# 514/514 [==============================] - 105s 205ms/step - loss: 3.4687e-04 - acc: 0.9998 - precision: 0.9995 - recall: 1.0000
# Epoch 10/50
# 514/514 [==============================] - 104s 202ms/step - loss: 3.5343e-04 - acc: 0.9996 - precision: 0.9998 - recall: 0.9995
# Epoch 11/50
# 514/514 [==============================] - 108s 210ms/step - loss: 3.6329e-04 - acc: 0.9996 - precision: 0.9995 - recall: 0.9998 - los
# Epoch 12/50
# 514/514 [==============================] - 105s 204ms/step - loss: 3.5454e-04 - acc: 0.9998 - precision: 0.9998 - recall: 0.9998
# Epoch 00012: early stopping
# 58/58 [==============================] - 1s 20ms/step - loss: 0.0281 - acc: 0.9912 - precision: 0.9933 - recall: 0.9889.0164 - acc: 0.9926 - prec
# ------------------------------------------------------------------------
# Training for fold 4 ...
# Epoch 1/50
# 514/514 [==============================] - 105s 204ms/step - loss: 0.0139 - acc: 0.9959 - precision: 0.9961 - recall: 0.9956
# Epoch 2/50
# 514/514 [==============================] - 92s 178ms/step - loss: 0.0110 - acc: 0.9968 - precision: 0.9971 - recall: 0.9966
# Epoch 3/50
# 514/514 [==============================] - 94s 183ms/step - loss: 0.0032 - acc: 0.9988 - precision: 0.9983 - recall: 0.9993
# Epoch 4/50
# 514/514 [==============================] - 105s 205ms/step - loss: 4.5352e-04 - acc: 0.9998 - precision: 0.9998 - recall: 0.9998 - loss: 4.7544e-0
# Epoch 5/50
# 514/514 [==============================] - 105s 204ms/step - loss: 3.7685e-04 - acc: 0.9998 - precision: 0.9998 - recall: 0.999815s - loss: 4.4264e-04 -
# Epoch 6/50
# 514/514 [==============================] - 107s 208ms/step - loss: 3.6193e-04 - acc: 0.9998 - precision: 0.9998 - recall: 0.9998
# Epoch 7/50
# 514/514 [==============================] - 107s 207ms/step - loss: 3.4730e-04 - acc: 0.9998 - precision: 0.9998 - recall: 0.9998
# Epoch 8/50
# 514/514 [==============================] - 96s 186ms/step - loss: 3.5470e-04 - acc: 0.9998 - precision: 0.9998 - recall: 0.9998
# Epoch 9/50
# 514/514 [==============================] - 104s 203ms/step - loss: 3.4291e-04 - acc: 0.9998 - precision: 0.9998 - recall: 0.9998
# Epoch 10/50
# 514/514 [==============================] - 88s 171ms/step - loss: 3.4412e-04 - acc: 0.9998 - precision: 0.9998 - recall: 0.9998s - loss: 3.6044e-04
# Epoch 11/50
# 514/514 [==============================] - 105s 204ms/step - loss: 3.5049e-04 - acc: 0.9998 - precision: 0.9995 - recall: 1.000025s - loss: 4.6587e-04 - acc: 0.9997 - precision: 0.9994
# Epoch 12/50
# 514/514 [==============================] - 105s 204ms/step - loss: 3.2967e-04 - acc: 0.9999 - precision: 0.9998 - recall: 1.0000
# Epoch 13/50
# 514/514 [==============================] - 103s 200ms/step - loss: 3.4065e-04 - acc: 0.9996 - precision: 0.9998 - recall: 0.999543s - loss: 3.0736
# Epoch 14/50
# 514/514 [==============================] - 105s 203ms/step - loss: 3.6171e-04 - acc: 0.9998 - precision: 0.9998 - recall: 0.9998
# Epoch 15/50
# 514/514 [==============================] - 106s 206ms/step - loss: 3.3723e-04 - acc: 0.9998 - precision: 0.9995 - recall: 1.0000
# Epoch 00015: early stopping
# 58/58 [==============================] - 1s 24ms/step - loss: 0.0330 - acc: 0.9956 - precision: 0.9978 - recall: 0.9933.0384 - acc: 0.9949 - precision: 0.9974 - reca
# ------------------------------------------------------------------------
# Training for fold 5 ...
# Epoch 1/50
# 514/514 [==============================] - 92s 178ms/step - loss: 0.0100 - acc: 0.9977 - precision: 0.9973 - recall: 0.9980
# Epoch 2/50
# 514/514 [==============================] - 99s 192ms/step - loss: 0.0092 - acc: 0.9971 - precision: 0.9973 - recall: 0.9968
# Epoch 3/50
# 514/514 [==============================] - 104s 202ms/step - loss: 0.0020 - acc: 0.9995 - precision: 0.9998 - recall: 0.9993
# Epoch 4/50
# 514/514 [==============================] - 107s 208ms/step - loss: 3.4097e-04 - acc: 0.9999 - precision: 1.0000 - recall: 0.9998
# Epoch 5/50
# 514/514 [==============================] - 105s 203ms/step - loss: 1.8533e-04 - acc: 0.9999 - precision: 0.9998 - recall: 1.0000
# Epoch 6/50
# 514/514 [==============================] - 91s 177ms/step - loss: 1.8879e-04 - acc: 0.9999 - precision: 1.0000 - recall: 0.9998s - loss: 2.0782e-04 - acc: 0.9999 - precision: 1.000
# Epoch 7/50
# 514/514 [==============================] - 106s 207ms/step - loss: 1.7175e-04 - acc: 0.9999 - precision: 1.0000 - recall: 0.9998
# Epoch 8/50
# 514/514 [==============================] - 104s 203ms/step - loss: 1.9411e-04 - acc: 0.9999 - precision: 0.9998 - recall: 1.0000
# Epoch 9/50
# 514/514 [==============================] - 105s 205ms/step - loss: 1.6500e-04 - acc: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 10/50
# 514/514 [==============================] - 105s 205ms/step - loss: 1.8662e-04 - acc: 0.9998 - precision: 0.9998 - recall: 0.9998
# Epoch 11/50
# 514/514 [==============================] - 96s 187ms/step - loss: 1.7109e-04 - acc: 0.9999 - precision: 0.9998 - recall: 1.0000
# Epoch 12/50
# 514/514 [==============================] - 102s 198ms/step - loss: 1.6221e-04 - acc: 0.9999 - precision: 0.9998 - recall: 1.000038s - loss: 2.8152e-04 - acc: 0.9998 - prec
# Epoch 13/50
# 514/514 [==============================] - 105s 205ms/step - loss: 1.9782e-04 - acc: 0.9999 - precision: 1.0000 - recall: 0.9998
# Epoch 14/50
# 514/514 [==============================] - 91s 178ms/step - loss: 1.9807e-04 - acc: 0.9999 - precision: 0.9998 - recall: 1.0000
# Epoch 15/50
# 514/514 [==============================] - 104s 202ms/step - loss: 1.8268e-04 - acc: 0.9999 - precision: 1.0000 - recall: 0.9998
# Epoch 00015: early stopping
# 58/58 [==============================] - 1s 25ms/step - loss: 0.0386 - acc: 0.9934 - precision: 0.9957 - recall: 0.9915
# ------------------------------------------------------------------------
# Training for fold 6 ...
# Epoch 1/50
# 514/514 [==============================] - 105s 204ms/step - loss: 0.0131 - acc: 0.9967 - precision: 0.9968 - recall: 0.9966
# Epoch 2/50
# 514/514 [==============================] - 105s 204ms/step - loss: 0.0049 - acc: 0.9983 - precision: 0.9985 - recall: 0.9981
# Epoch 3/50
# 514/514 [==============================] - 79s 154ms/step - loss: 5.0577e-04 - acc: 0.9999 - precision: 0.9998 - recall: 1.0000
# Epoch 4/50
# 514/514 [==============================] - 75s 146ms/step - loss: 7.9778e-04 - acc: 0.9996 - precision: 0.9995 - recall: 0.9998
# Epoch 5/50
# 514/514 [==============================] - 75s 146ms/step - loss: 2.2081e-04 - acc: 0.9999 - precision: 1.0000 - recall: 0.9998
# Epoch 6/50
# 514/514 [==============================] - 80s 155ms/step - loss: 2.1023e-04 - acc: 0.9999 - precision: 0.9998 - recall: 1.0000s -
# Epoch 7/50
# 514/514 [==============================] - 76s 148ms/step - loss: 1.7872e-04 - acc: 0.9999 - precision: 1.0000 - recall: 0.9998
# Epoch 8/50
# 514/514 [==============================] - 77s 149ms/step - loss: 1.8516e-04 - acc: 0.9999 - precision: 1.0000 - recall: 0.9998
# Epoch 9/50
# 514/514 [==============================] - 75s 145ms/step - loss: 1.6712e-04 - acc: 0.9999 - precision: 1.0000 - recall: 0.9998
# Epoch 10/50
# 514/514 [==============================] - 75s 146ms/step - loss: 1.8389e-04 - acc: 0.9998 - precision: 0.9998 - recall: 0.9998s - los
# Epoch 11/50
# 514/514 [==============================] - 75s 147ms/step - loss: 1.9362e-04 - acc: 0.9999 - precision: 1.0000 - recall: 0.9998s - loss: 2.0366e
# Epoch 12/50
# 514/514 [==============================] - 74s 144ms/step - loss: 1.8490e-04 - acc: 0.9998 - precision: 0.9998 - recall: 0.9998
# Epoch 00012: early stopping
# 58/58 [==============================] - 1s 18ms/step - loss: 0.0126 - acc: 0.9978 - precision: 0.9977 - recall: 0.9977
# ------------------------------------------------------------------------
# Training for fold 7 ...
# Epoch 1/50
# 514/514 [==============================] - 66s 128ms/step - loss: 0.0107 - acc: 0.9966 - precision: 0.9961 - recall: 0.9971
# Epoch 2/50
# 514/514 [==============================] - 74s 143ms/step - loss: 0.0049 - acc: 0.9985 - precision: 0.9990 - recall: 0.9981 14s - loss: 0.0058 - acc: 0.9983 - ETA
# Epoch 3/50
# 514/514 [==============================] - 74s 144ms/step - loss: 4.0266e-04 - acc: 0.9998 - precision: 1.0000 - recall: 0.9995 0s - loss: 4.0532e-04 - acc: 0.9998 - precision: 1.0000 - reca
# Epoch 4/50
# 514/514 [==============================] - 74s 144ms/step - loss: 3.8158e-04 - acc: 0.9998 - precision: 0.9998 - recall: 0.9998
# Epoch 5/50
# 514/514 [==============================] - 74s 144ms/step - loss: 3.5924e-04 - acc: 0.9998 - precision: 1.0000 - recall: 0.9995
# Epoch 6/50
# 514/514 [==============================] - 73s 142ms/step - loss: 3.5277e-04 - acc: 0.9996 - precision: 0.9995 - recall: 0.9998
# Epoch 7/50
# 514/514 [==============================] - 74s 143ms/step - loss: 3.5688e-04 - acc: 0.9998 - precision: 0.9995 - recall: 1.0000 14s - loss: 4.4874e-04 - acc: 0.9997 - preci - ETA: 10s - loss: 4 - ETA: 6s - loss: 3.9059e-04 - acc: 0.9997 - precision: 0.9995 - re
# Epoch 8/50
# 514/514 [==============================] - 67s 130ms/step - loss: 3.4255e-04 - acc: 0.9998 - precision: 1.0000 - recall: 0.9995
# Epoch 9/50
# 514/514 [==============================] - 75s 145ms/step - loss: 4.0253e-04 - acc: 0.9995 - precision: 0.9995 - recall: 0.9995s - loss: 4.1747e-04 - acc: 0.9
# Epoch 10/50
# 514/514 [==============================] - 73s 143ms/step - loss: 3.3600e-04 - acc: 0.9998 - precision: 0.9998 - recall: 0.9998s - loss:
# Epoch 11/50
# 514/514 [==============================] - 73s 142ms/step - loss: 3.4262e-04 - acc: 0.9998 - precision: 0.9998 - recall: 0.9998
# Epoch 12/50
# 514/514 [==============================] - 73s 142ms/step - loss: 3.4407e-04 - acc: 0.9996 - precision: 0.9998 - recall: 0.9995s - loss: 3.5828e-04 - acc:
# Epoch 13/50
# 514/514 [==============================] - 77s 149ms/step - loss: 3.3840e-04 - acc: 0.9998 - precision: 0.9998 - recall: 0.9998
# Epoch 00013: early stopping
# 57/57 [==============================] 0.0041 - acc: 0.9978 - precision: 1.0000 - recall: 0.99 - 1s 20ms/step - loss: 0.0041 - acc: 0.9978 - precision: 1.0000 - recall: 0.9956
# ------------------------------------------------------------------------
# Training for fold 8 ...
# Epoch 1/50
# 514/514 [==============================] - 80s 157ms/step - loss: 0.0055 - acc: 0.9982 - precision: 0.9981 - recall: 0.9983
# Epoch 2/50
# 514/514 [==============================] - 77s 149ms/step - loss: 0.0027 - acc: 0.9989 - precision: 0.9990 - recall: 0.9988s - los
# Epoch 3/50
# 514/514 [==============================] - 81s 157ms/step - loss: 4.5745e-04 - acc: 0.9996 - precision: 0.9998 - recall: 0.9995 20s - loss: 6.30 - ETA:
# Epoch 4/50
# 514/514 [==============================] - 61s 120ms/step - loss: 2.8704e-04 - acc: 0.9999 - precision: 1.0000 - recall: 0.9998
# Epoch 5/50
# 514/514 [==============================] - 57s 111ms/step - loss: 2.7130e-04 - acc: 0.9998 - precision: 1.0000 - recall: 0.9995
# Epoch 6/50
# 454/514 [=========================>....] - ETA: 6s - loss: 2.9911e-04 - acc: 0.9999 - precision: 0.9997 - recall: 1.0000

# %%
def Average(lst):
    return sum(lst) / len(lst)

# %%
print('test Accuracy: %f' % (Average(acc)))
print('test precision: %f' % (Average(pre)))
print('test recall: %f' % (Average(rec)))
print('test f1_score: %f' % (Average(f1)))
